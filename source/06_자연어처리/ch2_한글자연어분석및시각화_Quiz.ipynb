# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:95% !important;}
div.cell.code_cell.rendered{width:95%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:22pt;}
.inner_cell{font-size:22pt;}
div.text_cell_render pre code {font-size:22pt; line-height:30px;}
div.output {font-size:20pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:22pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render li{font-size:20pt;padding:5px; line-height:30px;}
table.dataframe{font-size:22px;}
</style>
"""))
# Out:
# <style>
# div.container{width:95% !important;}
# div.cell.code_cell.rendered{width:95%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:22pt;}
# .inner_cell{font-size:22pt;}
# div.text_cell_render pre code {font-size:22pt; line-height:30px;}
# div.output {font-size:20pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:22pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render li{font-size:20pt;padding:5px; line-height:30px;}
# table.dataframe{font-size:22px;}
# </style>

# %% [markdown]
# # ※ Quiz : 경주여행과 전주여행에 대해 최빈단어시각화와 유사도분석
# - (1) naver open API를 활용하여 블로그에 "경주여행", "전주여행"을 각각 500건씩 검색하여 백업(data/quiz/naver.csv)
#     * 파일 내용 : query, no, title, link, description, total_text(title + ' ' + description)
# - (2) naver.csv에서 total_text를 품사태깅(naver_pos.csv)
#     * 파일 내용 : query, no, token, pos
# - (3) 명사만 추출(naver_pos_nouns.csv)
#     * query, token, pos
# - (4) 빈도분석 백업(naver_pos_nouns_count.csv)
#     * token, 경주빈도, 전주빈도, 빈도합
# - (5) 빈도 시각화(워드클라우드, Text.plot)
#     * 이미지 저장
# - (6) 단어간 거리 분석(Word2Vec)
#
# ## 1. 네이버 open API 활용하여 검색 추출
# - query, no, title, link, description, total_text(title + ' ' + description)

# %%
# .env가져오기
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
# 네이버 개발자 센터에 있는 소스를 가져오기
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = os.getenv('CLIENT_ID')
client_secret = os.getenv('CLIENT_SECRET')
encText = urllib.parse.quote("경주 여행")
url = "https://openapi.naver.com/v1/search/blog.json?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8')[:200])
    # items = json.loads(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 04 Sep 2026 09:38:23 +0900",
# 	"total":2737319,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"3월의 <b>경주여행<\/b>.",
# 			"link":"https:\/\/lje77777.tistory.com\/7132",
# 			"

# %%
# 문자->dict
import json
from html import unescape # description에 있는 &lt;(특수문자)를 <로 변경
import requests
import pandas as pd
import re  # 특수문자 제거 @@ _._

# %%
query = "경주 여행"
start = 1
#url = f"https://openapi.naver.com/v1/search/blog.json?query={query}&display=100&start={start}"
url = "https://openapi.naver.com/v1/search/blog.json"
params = {
    'query':query,
    'display':100,
    'start':start
}
headers = {
    "X-Naver-Client-Id":client_id,
    "X-Naver-Client-Secret":client_secret
}
response = requests.get(url, headers=headers, params=params)
# 문자 -> dict
# items = json.loads(response.text)['items']
items = response.json()['items']
items[4]
# Out:
# {'title': '경북 <b>경주여행</b>/불국사-단아함과 정숙함이 묻어나는 겹벚꽃(왕벚꽃)....',
#  'link': 'https://skdywjd25.tistory.com/5973',
#  'description': '벚꽃이 다 지고나면 피는 겹벗꽃 봄 <b>여행</b>을 즐기는 고수라면 서둘러 <b>경주</b>행 티켓을 예약하자. 또다시 <b>경주</b>가 들썩이고 있다.다 <b>경주</b>지역 벚꽃은 거의 떨어지고 불국사 쪽이 겹벚꽃으로 유명하다. 불국사 입구에... ',
#  'bloggername': '산행과여행 사진으로 말한다',
#  'bloggerlink': 'https://skdywjd25.tistory.com/',
#  'postdate': '20190425'}

# %%
# title과 description의 <b>없애기, html의 특수문자없애기, 일반특수 없애기
item = items[4]
title = item['title'].replace('<b>', ' ').replace('</b>', ' ')
title = unescape(title)
title = re.sub(r'[^a-zA-Z0-9가-힣]', ' ', title)
description = item['description'].replace('<b>', ' ').replace('</b>', ' ')
description = unescape(description)
description = re.sub(r'[^a-zA-Z0-9가-힣]', ' ', description)
link = item['link']
totaltext = title + ' ' + description
print(totaltext)
print(link)
# Out:
# 경북  경주여행  불국사 단아함과 정숙함이 묻어나는 겹벚꽃 왕벚꽃      벚꽃이 다 지고나면 피는 겹벗꽃 봄  여행 을 즐기는 고수라면 서둘러  경주 행 티켓을 예약하자  또다시  경주 가 들썩이고 있다 다  경주 지역 벚꽃은 거의 떨어지고 불국사 쪽이 겹벚꽃으로 유명하다  불국사 입구에
# https://skdywjd25.tistory.com/5973

# %%
# re 정규표현식을 이용해서 특수문자 없애기
title = '[여행] ## & ktx 타고 짱 ㅋㅋ ㅠㅠ'
re.sub(r'[^a-zA-Z0-9가-힣]', ' ', title)
# Out:
# ' 여행       ktx 타고 짱      '

# %%
# 네이버 API 정보 및 검색 정보
from dotenv import load_dotenv
import os
load_dotenv()
client_id = os.getenv('CLIENT_ID')
client_secret = os.getenv('CLIENT_SECRET')

# %%
def get_search_item_return(query, start):
    'query, no, title, link, description, total_text(title + ' ' + description)'
    import requests
    # import json
    from html import unescape # html 특수문자 제거(ex. &nbsp; 제거)
    import re # 일반 특수문제 제거(__.__제거 )
    from dotenv import load_dotenv
    import os
    load_dotenv() # .env파일 읽어오기(환경변수 설정)
    client_id = os.getenv('CLIENT_ID')
    client_secret = os.getenv('CLIENT_SECRET')
    url = "https://openapi.naver.com/v1/search/blog.json"
    params = {
        'query':query,
        'display':100,
        'start':start
    }
    headers = {
        "X-Naver-Client-Id":client_id,
        "X-Naver-Client-Secret":client_secret
    }
    response = requests.get(url, headers=headers, params=params)
    # 문자 -> dict
    # items = json.loads(response.text)['items']
    items = response.json()['items'] # 100개
    result = [] # items의 title,link,description등을 dict list로 append
    for i, item in enumerate(items):        
        no = (start-1)*100 + i+1 # start가 1일때는 1,2,3.. start가 2일때는 101, 102,..
        title = item['title'].replace('<b>', ' ').replace('</b>', ' ')
        title = unescape(title)
        title = re.sub(r'[^a-zA-Z0-9가-힣]', ' ', title)
        link = item['link']
        description = item['description'].replace('<b>', ' ').replace('</b>', ' ')
        description = unescape(description)
        description = re.sub(r'[^a-zA-Z0-9가-힣]', ' ', description)
        total_text = title + ' ' + description
        #print(query, no, title[:5], link, description[:5], total_text[:5])
        result.append({'query': query,
                      'no'    : no,
                      'title' : title,
                      'link'  : link,
                      'description':description,
                      'total_text' :total_text
                      })
    return result

get_search_item_return('경주 여행', 4)
# Out:
# [{'query': '경주 여행',
#   'no': 301,
#   'title': '경북  경주여행  1일차 하얀 목련이 필때면    경주  대릉원 목련 낮풍경    ',
#   'link': 'https://skdywjd25.tistory.com/5890',
#   'description': '최근  경주 를  여행 하는 이들이 꼭 빼놓지 않는  여행 코스가 있다  다름 아닌  경주 의 야경을 둘러보는 것     연인과 함께  경주 여행 을 떠나게 될 당신을 위한 야경 투어 코스를 소개한다   경주 여행 을 준비하고 있는    ',
#   'total_text': '경북  경주여행  1일차 하얀 목련이 필때면    경주  대릉원 목련 낮풍경     최근  경주 를  여행 하는 이들이 꼭 빼놓지 않는  여행 코스가 있다  다름 아닌  경주 의 야경을 둘러보는 것     연인과 함께  경주 여행 을 떠나게 될 당신을 위한 야경 투어 코스를 소개한다   경주 여행 을 준비하고 있는    '},
#  {'query': '경주 여행',
#   'no': 302,
#   'title': '경북  경주여행  왕의 다리   경주  월정교      18년7월21일 ',
#   'link': 'https://skdywjd25.tistory.com/5502',
#   'description': '잠시 교촌마을에 도착하니 뜻하지 않은 행사에 잠시 쉬어간다 최근  경주 를  여행 하는 이들이 꼭 빼놓지    연인과 함께  경주 여행 을 떠나게 될 당신을 위한 야경 투어 코스를 소개한다   경주 여행 을 준비하고 있는    ',
#   'total_text': '경북  경주여행  왕의 다리   경주  월정교      18년7월21일  잠시 교촌마을에 도착하니 뜻하지 않은 행사에 잠시 쉬어간다 최근  경주 를  여행 하는 이들이 꼭 빼놓지    연인과 함께  경주 여행 을 떠나게 될 당신을 위한 야경 투어 코스를 소개한다   경주 여행 을 준비하고 있는    '},
#  {'query': '경주 여행',
#   'no': 303,
#   'title': '14개월 아기랑  경주여행  후기  정글의 법칙 미디어 파크  버드파크      ',
#   'link': 'https://ttottoro.tistory.com/912',
#   'description': '그래도  여행  일정중에 비가온다면 다녀오기 딱 좋은 곳 같다   경주  버드파크 위치  경북  경주 시 보문로 74 14  북군동 185 1  전화  054 777 7200 운영시간  10 00   19 00 입장료   대인  20 000원  소인  15 000원    ',
#   'total_text': '14개월 아기랑  경주여행  후기  정글의 법칙 미디어 파크  버드파크       그래도  여행  일정중에 비가온다면 다녀오기 딱 좋은 곳 같다   경주  버드파크 위치  경북  경주 시 보문로 74 14  북군동 185 1  전화  054 777 7200 운영시간  10 00   19 00 입장료   대인  20 000원  소인  15 000원    '},
#  {'query': '경주 여행',
#   'no': 304,
#   'title': ' 경주여행  보문단지 벚꽃은 보문호반길 화사한 봄 선사하는 벗꽃 17    ',
#   'link': 'https://skdywjd25.tistory.com/4657',
#   'description': '최적의  여행 지이다  차없는 도로 및 벗꽃길 이른 시각에 와야 제대로 힐링 되는 곳이다  만개해 아름다운 경관을 이루고 있다  경주 보문단지는  경주 시가지에서 동쪽으로 약 10여  정도 떨어진 명활산 옛성터에    ',
#   'total_text': ' 경주여행  보문단지 벚꽃은 보문호반길 화사한 봄 선사하는 벗꽃 17     최적의  여행 지이다  차없는 도로 및 벗꽃길 이른 시각에 와야 제대로 힐링 되는 곳이다  만개해 아름다운 경관을 이루고 있다  경주 보문단지는  경주 시가지에서 동쪽으로 약 10여  정도 떨어진 명활산 옛성터에    '},
#  {'query': '경주 여행',
#   'no': 305,
#   'title': '설레임 패밀리 일상',
#   'link': 'https://feelsogoodcamp.tistory.com/47',
#   'description': '오늘의 목적지는  경주  회사 제휴로 숙소를 저렴하게 예약하고  경주 로 나선다   경주 에 도착하자마자 배가 고파서 우리가족이 좋아하는 국수집을 찾아본다  와이프가 검색해서 찾아간 곳은 갈비랑 국수랑    ',
#   'total_text': '설레임 패밀리 일상 오늘의 목적지는  경주  회사 제휴로 숙소를 저렴하게 예약하고  경주 로 나선다   경주 에 도착하자마자 배가 고파서 우리가족이 좋아하는 국수집을 찾아본다  와이프가 검색해서 찾아간 곳은 갈비랑 국수랑    '},
#  {'query': '경주 여행',
#   'no': 306,
#   'title': ' 경주여행  세계문화유산  경주  양동마을 봄나들이 18년3월29일 ',
#   'link': 'https://skdywjd25.tistory.com/5250',
#   'description': '시간 여행 을 떠나고 싶다면 옛 조상들의 삶의 모습을 고스란히 간직한 채 수백 년의 숨결을 이어 온 양동마을이 제격이 아닐까  주소 경상북도  경주 시 강동면 양동마을길 138 18 지번 경상북도  경주 시 강동면    ',
#   'total_text': ' 경주여행  세계문화유산  경주  양동마을 봄나들이 18년3월29일  시간 여행 을 떠나고 싶다면 옛 조상들의 삶의 모습을 고스란히 간직한 채 수백 년의 숨결을 이어 온 양동마을이 제격이 아닐까  주소 경상북도  경주 시 강동면 양동마을길 138 18 지번 경상북도  경주 시 강동면    '},
#  {'query': '경주 여행',
#   'no': 307,
#   'title': '경북  경주여행  불국사 단아함과 정숙함이 묻어나는 겹벚꽃 왕벚꽃     ',
#   'link': 'https://skdywjd25.tistory.com/5973',
#   'description': '벚꽃이 다 지고나면 피는 겹벗꽃 봄  여행 을 즐기는 고수라면 서둘러  경주 행 티켓을 예약하자  또다시  경주 가 들썩이고 있다 다  경주 지역 벚꽃은 거의 떨어지고 불국사 쪽이 겹벚꽃으로 유명하다  불국사 입구에    ',
#   'total_text': '경북  경주여행  불국사 단아함과 정숙함이 묻어나는 겹벚꽃 왕벚꽃      벚꽃이 다 지고나면 피는 겹벗꽃 봄  여행 을 즐기는 고수라면 서둘러  경주 행 티켓을 예약하자  또다시  경주 가 들썩이고 있다 다  경주 지역 벚꽃은 거의 떨어지고 불국사 쪽이 겹벚꽃으로 유명하다  불국사 입구에    '},
#  {'query': '경주 여행',
#   'no': 308,
#   'title': ' 경주 여행 에서 많은 사람들이 지나치는 곳',
#   'link': 'https://colreda.tistory.com/98',
#   'description': '몇몇 지인들의 경험과 제 생각을 더해   경주 여행 에서 좀 더 주목하면 좋을 만한 장소들을 정리해    고즈넉한 산사  옥천사  경주 는 수학 여행 의 성지이자 역사 탐방의 중심지로 알려져 있지만  그 주변으로    ',
#   'total_text': ' 경주 여행 에서 많은 사람들이 지나치는 곳 몇몇 지인들의 경험과 제 생각을 더해   경주 여행 에서 좀 더 주목하면 좋을 만한 장소들을 정리해    고즈넉한 산사  옥천사  경주 는 수학 여행 의 성지이자 역사 탐방의 중심지로 알려져 있지만  그 주변으로    '},
#  {'query': '경주 여행',
#   'no': 309,
#   'title': ' 경주여행  야경이 이쁜 안압지 첨성대 16년3월31일 ',
#   'link': 'https://skdywjd25.tistory.com/4030',
#   'description': '어울린다  경주 여행 에서 빠질수 없는 관광지 중 하나인 첨성대   첨성대는 신라시대에 별을 관측하기        최근  경주 를  여행 하는 이들이 꼭 빼놓지 않는  여행 코스가 있다  다름 아닌  경주 의 야경을 둘러보는 것     ',
#   'total_text': ' 경주여행  야경이 이쁜 안압지 첨성대 16년3월31일  어울린다  경주 여행 에서 빠질수 없는 관광지 중 하나인 첨성대   첨성대는 신라시대에 별을 관측하기        최근  경주 를  여행 하는 이들이 꼭 빼놓지 않는  여행 코스가 있다  다름 아닌  경주 의 야경을 둘러보는 것     '},
#  {'query': '경주 여행',
#   'no': 310,
#   'title': '  여행  울산  경주 여행  Part4   동궁과 월지  빛누리정원  성호리조트',
#   'link': 'https://jinstistory.tistory.com/138',
#   'description': '장생포는 고래문화특구 라는 이름으로 고래를 주제로 한 다채로운 관광지를 형성해두었는데 사실 고래박물관이나 생태체 jinstistory tistory com 2023 08 16     여행  국내 여행       여행  울산  경주 여행  Part3    경주     ',
#   'total_text': '  여행  울산  경주 여행  Part4   동궁과 월지  빛누리정원  성호리조트 장생포는 고래문화특구 라는 이름으로 고래를 주제로 한 다채로운 관광지를 형성해두었는데 사실 고래박물관이나 생태체 jinstistory tistory com 2023 08 16     여행  국내 여행       여행  울산  경주 여행  Part3    경주     '},
#  {'query': '경주 여행',
#   'no': 311,
#   'title': '루비의 정원    설연휴  경주 여행   신 경주 역에서 시작하세요',
#   'link': 'https://rubygarden.tistory.com/897',
#   'description': ' 신청은 신 경주 역  여행  센터  광활한 부지에 자리잡은 신 경주 역은 역사 마당도 엄청나게 너른데    연휴  여행 을 계획하고 계신 분은 KTX를 이용한  경주 여행 은 어떠하신지       Copyright 2011  루비  All pictures    ',
#   'total_text': '루비의 정원    설연휴  경주 여행   신 경주 역에서 시작하세요  신청은 신 경주 역  여행  센터  광활한 부지에 자리잡은 신 경주 역은 역사 마당도 엄청나게 너른데    연휴  여행 을 계획하고 계신 분은 KTX를 이용한  경주 여행 은 어떠하신지       Copyright 2011  루비  All pictures    '},
#  {'query': '경주 여행',
#   'no': 312,
#   'title': ' 경주 여행  출장  깨끗하고 조식이 제공되는 에이치에비뉴 호텔을 소    ',
#   'link': 'https://realestate-k.tistory.com/310',
#   'description': ' 경주  불국사까지 도보로 단 15분 거리에 있어서   여행 의 피로함을 조금이나마 덜 수 있었습니다  아침 일찍 불국사를 방문해 한적하고 고요한 분위기 속에서 산책을 즐기기에 최적의 위치였습니다  꿀스테이    ',
#   'total_text': ' 경주 여행  출장  깨끗하고 조식이 제공되는 에이치에비뉴 호텔을 소      경주  불국사까지 도보로 단 15분 거리에 있어서   여행 의 피로함을 조금이나마 덜 수 있었습니다  아침 일찍 불국사를 방문해 한적하고 고요한 분위기 속에서 산책을 즐기기에 최적의 위치였습니다  꿀스테이    '},
#  {'query': '경주 여행',
#   'no': 313,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/get/12265469',
#   'description': '일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점   역사를 사랑하고 덕질하는 사람의 눈으로 바라본  경주   아는 만큼 보이고  사랑하는    ',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점   역사를 사랑하고 덕질하는 사람의 눈으로 바라본  경주   아는 만큼 보이고  사랑하는    '},
#  {'query': '경주 여행',
#   'no': 314,
#   'title': ' 경주여행  20200727',
#   'link': 'https://dravin.tistory.com/170',
#   'description': '08 02  경주여행  20200728  0  2020 08 02  경주여행  20200727  0  2020 08 02 1일 3평화  0  2020 07 13 강릉 여행  서나무  0  2020 07 08 강릉 여행   0  2020 07 08',
#   'total_text': ' 경주여행  20200727 08 02  경주여행  20200728  0  2020 08 02  경주여행  20200727  0  2020 08 02 1일 3평화  0  2020 07 13 강릉 여행  서나무  0  2020 07 08 강릉 여행   0  2020 07 08'},
#  {'query': '경주 여행',
#   'no': 315,
#   'title': '  경주여행   한옥 숙소   소설재 첨성대점 비향 15만원 ',
#   'link': 'https://jisuni-1116.tistory.com/330',
#   'description': ' 경주여행  한옥숙소 이름도 특이한  소설재  첨성대점  첨성대랑 진짜 가까워서 첨성대점인듯     낮에도 이쁘고  밤에는 더더 이쁜 한옥  소설재 너무너무너무 인기있는 곳이라서 주말에 묶으려면    ',
#   'total_text': '  경주여행   한옥 숙소   소설재 첨성대점 비향 15만원   경주여행  한옥숙소 이름도 특이한  소설재  첨성대점  첨성대랑 진짜 가까워서 첨성대점인듯     낮에도 이쁘고  밤에는 더더 이쁜 한옥  소설재 너무너무너무 인기있는 곳이라서 주말에 묶으려면    '},
#  {'query': '경주 여행',
#   'no': 316,
#   'title': ' 알라딘서재 황금호두 열리면 무웅이와 함께 떠나는  경주여행 ',
#   'link': 'https://blog.aladin.co.kr/702675155/3004258',
#   'description': '코스의  여행 인데도 매 번 새로운 느낌이 들어 자꾸만  경주 를 찾게 되는것 같다 매 번 새로운 느낌을 주는  경주여행 에 푹 빠져있는데 신라에서 온 아이와 함께하는  경주여행 은 더 새롭게 다가왔다 한참 티비에서    ',
#   'total_text': ' 알라딘서재 황금호두 열리면 무웅이와 함께 떠나는  경주여행  코스의  여행 인데도 매 번 새로운 느낌이 들어 자꾸만  경주 를 찾게 되는것 같다 매 번 새로운 느낌을 주는  경주여행 에 푹 빠져있는데 신라에서 온 아이와 함께하는  경주여행 은 더 새롭게 다가왔다 한참 티비에서    '},
#  {'query': '경주 여행',
#   'no': 317,
#   'title': ' 경주여행 ',
#   'link': 'https://gyeongnamtravel.tistory.com/33',
#   'description': ' 경주 까지 이동은 기차 여행   경주 내에서는 자전거 여행  도보 여행  버스투어 모두 가능하다  경주여행 코스   시내권    천마총   왕릉   첨성대   계림   포석정   안압지    ',
#   'total_text': ' 경주여행   경주 까지 이동은 기차 여행   경주 내에서는 자전거 여행  도보 여행  버스투어 모두 가능하다  경주여행 코스   시내권    천마총   왕릉   첨성대   계림   포석정   안압지    '},
#  {'query': '경주 여행',
#   'no': 318,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/703617255/12092226',
#   'description': '일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이    못한 지가 한참 되었는데 오랜만에 저자와 함께  경주 를 걸으며 역사  여행 을 하는 느낌을 주는 책이네요 ',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이    못한 지가 한참 되었는데 오랜만에 저자와 함께  경주 를 걸으며 역사  여행 을 하는 느낌을 주는 책이네요 '},
#  {'query': '경주 여행',
#   'no': 319,
#   'title': ' 경주여행  감포 여행  송대말등대빛체험전시관  여행 ',
#   'link': 'https://onlylove1976.tistory.com/224',
#   'description': '위치  경북  경주 시 척사길 18 94 2  운영시간   09 00   18 00 3  연중무휴 4  대표전화   054 744 3233 5  입장료   무료 송대말등대 빛 체험관은 아이와 함께  여행 가기에 좋고 점심시간 12 00   13 00 운영을 안하니    ',
#   'total_text': ' 경주여행  감포 여행  송대말등대빛체험전시관  여행  위치  경북  경주 시 척사길 18 94 2  운영시간   09 00   18 00 3  연중무휴 4  대표전화   054 744 3233 5  입장료   무료 송대말등대 빛 체험관은 아이와 함께  여행 가기에 좋고 점심시간 12 00   13 00 운영을 안하니    '},
#  {'query': '경주 여행',
#   'no': 320,
#   'title': ' 경주여행 코스 읍천항 주상절리 파도소리길',
#   'link': 'https://sunhea0729.tistory.com/81',
#   'description': ' 경주 에는 주상절리가 제주도만큼이나 이쁜 곳이 있다  게다가 조용한 읍천항을 끼고 있어 더 좋았던  경주여행 코스  읍천항옆에 자리한 주상절리 파도소리길은 넓은 주차장도 갖추고 있어 길을 따라 등대까지    ',
#   'total_text': ' 경주여행 코스 읍천항 주상절리 파도소리길  경주 에는 주상절리가 제주도만큼이나 이쁜 곳이 있다  게다가 조용한 읍천항을 끼고 있어 더 좋았던  경주여행 코스  읍천항옆에 자리한 주상절리 파도소리길은 넓은 주차장도 갖추고 있어 길을 따라 등대까지    '},
#  {'query': '경주 여행',
#   'no': 321,
#   'title': ' 여행 이좋다     교리김밥      경주 맛집     경주여행 하면서 들린 김밥    ',
#   'link': 'https://noproblemyourlife.tistory.com/226',
#   'description': ' 경주  남산 등산을 포함해서 당일치기로  경주여행 을 계획하고 다녀왔습니다  그 첫번째 코스로  경주 에선    여하튼 저처럼  여행  중에 한번 정도는 가볼만한 집이라는 생각이네요  특히나 남산같은 산에    ',
#   'total_text': ' 여행 이좋다     교리김밥      경주 맛집     경주여행 하면서 들린 김밥      경주  남산 등산을 포함해서 당일치기로  경주여행 을 계획하고 다녀왔습니다  그 첫번째 코스로  경주 에선    여하튼 저처럼  여행  중에 한번 정도는 가볼만한 집이라는 생각이네요  특히나 남산같은 산에    '},
#  {'query': '경주 여행',
#   'no': 322,
#   'title': '안녕 2014년  경주 여행 ',
#   'link': 'https://lje77777.tistory.com/2737',
#   'description': '2014년을 그냥 보내기가 좀 아쉬워서 좋아하는  경주 로 기차타고 떠났다  몇일전엔 크리스마스  경주여행  오늘은 안녕 2014년  경주여행    이번  여행 은 럭셔리 컨셉으로 좋은 호텔에서    ',
#   'total_text': '안녕 2014년  경주 여행  2014년을 그냥 보내기가 좀 아쉬워서 좋아하는  경주 로 기차타고 떠났다  몇일전엔 크리스마스  경주여행  오늘은 안녕 2014년  경주여행    이번  여행 은 럭셔리 컨셉으로 좋은 호텔에서    '},
#  {'query': '경주 여행',
#   'no': 323,
#   'title': ' 알라딘서재  경주 여행  이야기',
#   'link': 'https://blog.aladin.co.kr/721307206/12092280',
#   'description': ' 일상이 고고학  나 혼자  경주 여행  은  경주 를 무대로 한  여행  에세이풍의 글을 만날 수 있는 책으로   경주 에서 유명한 문화재에 대한 사전 지식을 줄줄 읊는 것 외에도 얼마든지 재미있고 의미 있는  여행 을 할    ',
#   'total_text': ' 알라딘서재  경주 여행  이야기  일상이 고고학  나 혼자  경주 여행  은  경주 를 무대로 한  여행  에세이풍의 글을 만날 수 있는 책으로   경주 에서 유명한 문화재에 대한 사전 지식을 줄줄 읊는 것 외에도 얼마든지 재미있고 의미 있는  여행 을 할    '},
#  {'query': '경주 여행',
#   'no': 324,
#   'title': '  경주여행  3일차 놀부보쌈  경주  황오점 배달후기',
#   'link': 'https://aerim9327.tistory.com/1329',
#   'description': ' 경주여행  3번째 날 숙소로 황남관에 머물게 되었어요   여행  3일차 저녁이라 아이들도 지치고 저와    배민에 놀부보쌈 검색해보니  경주 황오점에서 배달이 가능하다고 나오네요  저희는 황남관에 머물었기 때문에    ',
#   'total_text': '  경주여행  3일차 놀부보쌈  경주  황오점 배달후기  경주여행  3번째 날 숙소로 황남관에 머물게 되었어요   여행  3일차 저녁이라 아이들도 지치고 저와    배민에 놀부보쌈 검색해보니  경주 황오점에서 배달이 가능하다고 나오네요  저희는 황남관에 머물었기 때문에    '},
#  {'query': '경주 여행',
#   'no': 325,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/784750170/12085359',
#   'description': '일상이 고고학  나 혼자  경주 여행    개정증보판  일상이 시리즈 3 황윤 지음   책읽는고양이   2020년 10월 평점    경주 는 학교다닐때 수학 여행 때 갔었는데 추억의 장소라 꼭 다시 가보고 싶은 곳이거든요     ',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  일상이 고고학  나 혼자  경주 여행    개정증보판  일상이 시리즈 3 황윤 지음   책읽는고양이   2020년 10월 평점    경주 는 학교다닐때 수학 여행 때 갔었는데 추억의 장소라 꼭 다시 가보고 싶은 곳이거든요     '},
#  {'query': '경주 여행',
#   'no': 326,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/769001152/12084760',
#   'description': ' 일상이 고고학  나 혼자  경주 여행  을 읽고  경주 의 모든 것이 박물관이 되는 즐거운 경험을 하고 싶습니다  어떤 가이드보다도 든든한  경주 여행  길잡이가 되어주겠네요 ',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행   일상이 고고학  나 혼자  경주 여행  을 읽고  경주 의 모든 것이 박물관이 되는 즐거운 경험을 하고 싶습니다  어떤 가이드보다도 든든한  경주 여행  길잡이가 되어주겠네요 '},
#  {'query': '경주 여행',
#   'no': 327,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/702898129/12092361',
#   'description': '일상이 고고학  나 혼자  경주 여행    개정증보판  일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점   신라 경주  마니아로부터 듣는  경주여행 기라 관심이 가요  고고학적인 관점으로는    ',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  일상이 고고학  나 혼자  경주 여행    개정증보판  일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점   신라 경주  마니아로부터 듣는  경주여행 기라 관심이 가요  고고학적인 관점으로는    '},
#  {'query': '경주 여행',
#   'no': 328,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/797054101/12079116',
#   'description': '일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이    대한 깊이있는 이야기와 호기심에 답해줍니다   경주 를 100번도 넘게 가봤다니 정말 대단한것 같습니다 ',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이    대한 깊이있는 이야기와 호기심에 답해줍니다   경주 를 100번도 넘게 가봤다니 정말 대단한것 같습니다 '},
#  {'query': '경주 여행',
#   'no': 329,
#   'title': '경북  경주여행   황룡사지 황화 코스모스 20년8월14일 ',
#   'link': 'https://skdywjd25.tistory.com/7105',
#   'description': ' 경주여행   황룡사지  황화 코스모스  20년8월14일   경주  지역의 낮 최고 기온이 36 1 를 기록하며 폭염특보가 내려진 상태 사진 담다가 햇빛에 타죽는줄 알았다  구황동 분황사지 앞 황룡사지 터에는    ',
#   'total_text': '경북  경주여행   황룡사지 황화 코스모스 20년8월14일   경주여행   황룡사지  황화 코스모스  20년8월14일   경주  지역의 낮 최고 기온이 36 1 를 기록하며 폭염특보가 내려진 상태 사진 담다가 햇빛에 타죽는줄 알았다  구황동 분황사지 앞 황룡사지 터에는    '},
#  {'query': '경주 여행',
#   'no': 330,
#   'title': ' 여행 이좋다     경주 석빙고    색다른  경주여행  볼거리    근처에 안압    ',
#   'link': 'https://noproblemyourlife.tistory.com/2099',
#   'description': ' 경주여행  색다른 볼거리  경주 석빙고 이번  경주여행 에서 다녀온  경주 석빙고입니다   경주  석빙고는 영조때에 만들어진 일종의 얼음창고로  근처에 첨성대를 비롯한 많은  여행 지들이 몰려있어서  함께 묶어    ',
#   'total_text': ' 여행 이좋다     경주 석빙고    색다른  경주여행  볼거리    근처에 안압      경주여행  색다른 볼거리  경주 석빙고 이번  경주여행 에서 다녀온  경주 석빙고입니다   경주  석빙고는 영조때에 만들어진 일종의 얼음창고로  근처에 첨성대를 비롯한 많은  여행 지들이 몰려있어서  함께 묶어    '},
#  {'query': '경주 여행',
#   'no': 331,
#   'title': '3월의  경주여행  ',
#   'link': 'https://lje77777.tistory.com/7132',
#   'description': '첨가본 동궁원  예쁜 꽃들 만나고 좋아하는 커피열매도 보고 비맞으면서 노천온천 잘먹고 잘쉬고 행복한  경주 여행  ',
#   'total_text': '3월의  경주여행   첨가본 동궁원  예쁜 꽃들 만나고 좋아하는 커피열매도 보고 비맞으면서 노천온천 잘먹고 잘쉬고 행복한  경주 여행  '},
#  {'query': '경주 여행',
#   'no': 332,
#   'title': ' 경주여행  황리단길 보문단지 왕릉탐방 데이트코스',
#   'link': 'https://a-kdh.tistory.com/340',
#   'description': 'https   youtu be  nZzijKooIk 밤의  황리단길 은 참 예쁘고 마음 한켠이 낭만으로 차오르는 경상도에서 흔치 않은 젊은거리 바로 옆은   경주 유적지 에 오래된 한옥  천년고도  경주 와는 사뭇 어울리면서도    ',
#   'total_text': ' 경주여행  황리단길 보문단지 왕릉탐방 데이트코스 https   youtu be  nZzijKooIk 밤의  황리단길 은 참 예쁘고 마음 한켠이 낭만으로 차오르는 경상도에서 흔치 않은 젊은거리 바로 옆은   경주 유적지 에 오래된 한옥  천년고도  경주 와는 사뭇 어울리면서도    '},
#  {'query': '경주 여행',
#   'no': 333,
#   'title': ' 경주여행 밀면',
#   'link': 'https://imsun202.tistory.com/15715529',
#   'description': ' 경주 에서 먹어본   경주여행 밀면  맛보기 가격도 착해 5000원 비빔밀면 물밀면도 5000원 더해먹는 떡갈비는 2000원 12 000원 밥상 그리고 뜨거운 육수까지 맛평가는 입맛따라 취향별로    나따루 너따루   ',
#   'total_text': ' 경주여행 밀면  경주 에서 먹어본   경주여행 밀면  맛보기 가격도 착해 5000원 비빔밀면 물밀면도 5000원 더해먹는 떡갈비는 2000원 12 000원 밥상 그리고 뜨거운 육수까지 맛평가는 입맛따라 취향별로    나따루 너따루   '},
#  {'query': '경주 여행',
#   'no': 334,
#   'title': '1박2일  경주여행   경주 엑스포대공원',
#   'link': 'https://achim84.tistory.com/6974805',
#   'description': '2025  08  16  토   푸른애벌레의 꿈   경주여행  둘째날  보문호 주변길 걷기  10시에  경주 엑스포대공원 입장   경주 엑스포기념관  천마의궁전   경주 타워  솔거미술관  자연사박물관 ',
#   'total_text': '1박2일  경주여행   경주 엑스포대공원 2025  08  16  토   푸른애벌레의 꿈   경주여행  둘째날  보문호 주변길 걷기  10시에  경주 엑스포대공원 입장   경주 엑스포기념관  천마의궁전   경주 타워  솔거미술관  자연사박물관 '},
#  {'query': '경주 여행',
#   'no': 335,
#   'title': '2020년 6월  경주여행  동방역 능소화 서출지 경북산림연구원 ',
#   'link': 'https://myarea1472.tistory.com/8369843',
#   'description': '2020년 6월25일 목   경주여행  동방역 능소화 서출지 경북산림연구원 ',
#   'total_text': '2020년 6월  경주여행  동방역 능소화 서출지 경북산림연구원  2020년 6월25일 목   경주여행  동방역 능소화 서출지 경북산림연구원 '},
#  {'query': '경주 여행',
#   'no': 336,
#   'title': '모녀와 함께  경주여행     바보곰 블로그',
#   'link': 'https://dmhtbear.tistory.com/15338683',
#   'description': '모녀와 함께한  경주여행  2019 10 15  첨성대 야생화단지  계림  월지 안압지    계림 월지 안압지 의 야경  경주 박물관 10 16  김유신장군 묘',
#   'total_text': '모녀와 함께  경주여행     바보곰 블로그 모녀와 함께한  경주여행  2019 10 15  첨성대 야생화단지  계림  월지 안압지    계림 월지 안압지 의 야경  경주 박물관 10 16  김유신장군 묘'},
#  {'query': '경주 여행',
#   'no': 337,
#   'title': ' 경주여행  석굴암',
#   'link': 'https://rlawogur119.tistory.com/8503358',
#   'description': '2018 10 7',
#   'total_text': ' 경주여행  석굴암 2018 10 7'},
#  {'query': '경주 여행',
#   'no': 338,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/725949182/12092239',
#   'description': '일상이 고고학  나 혼자  경주 여행    개정증보판  일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점   삼국 시대에 관한 거의 모든 자료를 섭렵한 소장 역사학자의 순수한 시각과 생생한    ',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  일상이 고고학  나 혼자  경주 여행    개정증보판  일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점   삼국 시대에 관한 거의 모든 자료를 섭렵한 소장 역사학자의 순수한 시각과 생생한    '},
#  {'query': '경주 여행',
#   'no': 339,
#   'title': ' 알라딘서재 일상이 고고학 나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/750352205/12089558',
#   'description': '일상이 고고학  나 혼자  경주 여행    개정증보판  일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점   수학 여행 으로 갔던  경주 의 추억을 또 다시 한번  경주 는 역사도 그렇고 알면 알수록    ',
#   'total_text': ' 알라딘서재 일상이 고고학 나 혼자  경주 여행  일상이 고고학  나 혼자  경주 여행    개정증보판  일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점   수학 여행 으로 갔던  경주 의 추억을 또 다시 한번  경주 는 역사도 그렇고 알면 알수록    '},
#  {'query': '경주 여행',
#   'no': 340,
#   'title': ' 경주여행 경비 2박3일  경주여행  혼자서 떠난  경주 ',
#   'link': 'https://winterstar.tistory.com/35',
#   'description': ' 2박3일  경주여행     이동수단   시외버스   경주  내 버스 택시  시티투어버스   2박3일    Total  13 140  기타 생필품    여행 용 샴푸   린스   바디워시   버블망    5 490 Total 경비  148 080',
#   'total_text': ' 경주여행 경비 2박3일  경주여행  혼자서 떠난  경주   2박3일  경주여행     이동수단   시외버스   경주  내 버스 택시  시티투어버스   2박3일    Total  13 140  기타 생필품    여행 용 샴푸   린스   바디워시   버블망    5 490 Total 경비  148 080'},
#  {'query': '경주 여행',
#   'no': 341,
#   'title': ' 경북  경주여행  현대호텔  경주 ',
#   'link': 'https://kwon-blog.tistory.com/1572',
#   'description': '  경주여행   경주  현대호텔 현대호텔  경주  보문수상공연장  경주  보문관광단지 보문호반길  경주 신라컨트리클럽   경주여행  숙박 현대호텔  방문일자  2016년 9월 7일 수  현대호텔  경주  경북  경주 시 신평동    ',
#   'total_text': ' 경북  경주여행  현대호텔  경주    경주여행   경주  현대호텔 현대호텔  경주  보문수상공연장  경주  보문관광단지 보문호반길  경주 신라컨트리클럽   경주여행  숙박 현대호텔  방문일자  2016년 9월 7일 수  현대호텔  경주  경북  경주 시 신평동    '},
#  {'query': '경주 여행',
#   'no': 342,
#   'title': ' 경주여행 3 석굴암 불국사 ',
#   'link': 'https://sokukyo.tistory.com/2090',
#   'description': '09 43  경주여행 3 석굴암 불국사     여행 일시   2011년4월22일 4월24일    여행 장소   세째날 4월24일    석굴암  불국사    여행 참여   우리가족 9명 송국영 안종순 송진주 김홍식 김연우 송연주 조광민    ',
#   'total_text': ' 경주여행 3 석굴암 불국사  09 43  경주여행 3 석굴암 불국사     여행 일시   2011년4월22일 4월24일    여행 장소   세째날 4월24일    석굴암  불국사    여행 참여   우리가족 9명 송국영 안종순 송진주 김홍식 김연우 송연주 조광민    '},
#  {'query': '경주 여행',
#   'no': 343,
#   'title': '  경주여행   대릉원  스탬프투어  그 다섯번째 이야기  대릉원천마    ',
#   'link': 'https://0572.tistory.com/356',
#   'description': '경북 여행     경주여행     경주 스탬프투어    경주 오릉 대릉원 천마총    경주 오릉 교촌마을 투어를 마치고 다음으로 찾아간 곳은 바로   경주 오릉  이다 교촌마을을 돌면서 조금 지치는 듯한 느낌이 있었는데 맛나는    ',
#   'total_text': '  경주여행   대릉원  스탬프투어  그 다섯번째 이야기  대릉원천마     경북 여행     경주여행     경주 스탬프투어    경주 오릉 대릉원 천마총    경주 오릉 교촌마을 투어를 마치고 다음으로 찾아간 곳은 바로   경주 오릉  이다 교촌마을을 돌면서 조금 지치는 듯한 느낌이 있었는데 맛나는    '},
#  {'query': '경주 여행',
#   'no': 344,
#   'title': '  경주여행  유적지 트레킹',
#   'link': 'https://jalsaljaulsan.tistory.com/16141787',
#   'description': ' 대상지    경주여행  유적지 트레킹   소재지   경북  경주 시  일 자   2023 10 1  코 스   동궁과월지 반월상 교촌 대릉원 쪽샘44호고분 분황사 황룡사역사문화원 동궁과월지주차장   약 9 0Km  반월성에서    ',
#   'total_text': '  경주여행  유적지 트레킹  대상지    경주여행  유적지 트레킹   소재지   경북  경주 시  일 자   2023 10 1  코 스   동궁과월지 반월상 교촌 대릉원 쪽샘44호고분 분황사 황룡사역사문화원 동궁과월지주차장   약 9 0Km  반월성에서    '},
#  {'query': '경주 여행',
#   'no': 345,
#   'title': ' 경주여행  동궁과 월지  안압지 야경보기 ',
#   'link': 'https://villaamalia.tistory.com/85',
#   'description': '해외  여행  이야기  여행  후기  경주여행  동궁과 월지  안압지 야경보기  훌리아 2020  3  25  15 17 2019년 여름  경주  사진 보관 1 구독하기  해외  여행  이야기  여행  후기  Related Articles    ',
#   'total_text': ' 경주여행  동궁과 월지  안압지 야경보기  해외  여행  이야기  여행  후기  경주여행  동궁과 월지  안압지 야경보기  훌리아 2020  3  25  15 17 2019년 여름  경주  사진 보관 1 구독하기  해외  여행  이야기  여행  후기  Related Articles    '},
#  {'query': '경주 여행',
#   'no': 346,
#   'title': '  경주 여행  이야기가 있는  경주여행 ',
#   'link': 'https://kwon-blog.tistory.com/1575',
#   'description': ' 여행  계명대학교  경주 동산병원  천년의 신라고도  경주여행    여행 일자  2016년 9월 7일 목    여행 인원  친구와 함께  경주 시외버스터미널 경북  경주 시 노서동 160 2 전화  1666 5599  경주 시외버스터미널    ',
#   'total_text': '  경주 여행  이야기가 있는  경주여행   여행  계명대학교  경주 동산병원  천년의 신라고도  경주여행    여행 일자  2016년 9월 7일 목    여행 인원  친구와 함께  경주 시외버스터미널 경북  경주 시 노서동 160 2 전화  1666 5599  경주 시외버스터미널    '},
#  {'query': '경주 여행',
#   'no': 347,
#   'title': ' 경주여행 ',
#   'link': 'https://cwh5513.tistory.com/203998',
#   'description': '2020년 06월 13 14일 토 일요일  오전 비 오후 맑음   경주 에서  고향친구들과 함께 신라대종 장맛비가 시작되는 육월중순 고향친구들과 함께  경주 에서 즐거운  여행 을 하다    대릉원 돌담길 걸어주고    황리단길도    ',
#   'total_text': ' 경주여행  2020년 06월 13 14일 토 일요일  오전 비 오후 맑음   경주 에서  고향친구들과 함께 신라대종 장맛비가 시작되는 육월중순 고향친구들과 함께  경주 에서 즐거운  여행 을 하다    대릉원 돌담길 걸어주고    황리단길도    '},
#  {'query': '경주 여행',
#   'no': 348,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/750669293/12074895',
#   'description': '일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이    재미있게  경주 를  여행 하는데 길잡이가 되어주는 책입니다   경주 를 더 풍부하게 이해할 수 있어    ',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이    재미있게  경주 를  여행 하는데 길잡이가 되어주는 책입니다   경주 를 더 풍부하게 이해할 수 있어    '},
#  {'query': '경주 여행',
#   'no': 349,
#   'title': ' 경주 여행 코스 베스트 추천 top 10',
#   'link': 'https://hotel-iu.tistory.com/2486',
#   'description': ' 경주 여행 코스 베스트 추천 top 10  경주 여행 코스 베스트 추천 top 10곳을 소개합니다  1  황리단길 상호명  황리단길 주소  경상북도  경주 시 황남동 280 전화번호  미입력 관련 키워드  키워드    ',
#   'total_text': ' 경주 여행 코스 베스트 추천 top 10  경주 여행 코스 베스트 추천 top 10  경주 여행 코스 베스트 추천 top 10곳을 소개합니다  1  황리단길 상호명  황리단길 주소  경상북도  경주 시 황남동 280 전화번호  미입력 관련 키워드  키워드    '},
#  {'query': '경주 여행',
#   'no': 350,
#   'title': '  경주  가볼만한 곳   경주 여행  코스 뚜벅이로 불국사  석굴암 대중교    ',
#   'link': 'https://loveartlove.tistory.com/368',
#   'description': 'naver com loveartlove 223054447834 다시 서울로 올라갈 채비를 했다   경주    경주여행    경주 불국사  불국사  봄 여행   국보  다보탑  석가탑  석굴암입장료   경주 가볼만한곳',
#   'total_text': '  경주  가볼만한 곳   경주 여행  코스 뚜벅이로 불국사  석굴암 대중교     naver com loveartlove 223054447834 다시 서울로 올라갈 채비를 했다   경주    경주여행    경주 불국사  불국사  봄 여행   국보  다보탑  석가탑  석굴암입장료   경주 가볼만한곳'},
#  {'query': '경주 여행',
#   'no': 351,
#   'title': '  경주여행   불국사  스탬프투어 그 세번째 이야기  불국사   석굴암',
#   'link': 'https://0572.tistory.com/354',
#   'description': '방쌤의  경주여행  경북 여행     경주여행     경주 스탬프투어   가을 여행  불국사   석굴암 동리목월문학관 구경을 마치고 다음으로 내가 찾을 장소는  경주여행 의 핵심   경주여행 의 메카  바로 불국사와 석굴암이다    ',
#   'total_text': '  경주여행   불국사  스탬프투어 그 세번째 이야기  불국사   석굴암 방쌤의  경주여행  경북 여행     경주여행     경주 스탬프투어   가을 여행  불국사   석굴암 동리목월문학관 구경을 마치고 다음으로 내가 찾을 장소는  경주여행 의 핵심   경주여행 의 메카  바로 불국사와 석굴암이다    '},
#  {'query': '경주 여행',
#   'no': 352,
#   'title': '  경주여행   황리단길 한옥카페추천  카페 아덴 2호점',
#   'link': 'https://dayaa.tistory.com/287',
#   'description': '카페 아덴 2호점 위치   경북  경주 시 사정로 57 운영시간   매일 10시     경주 와서 빵으로 배채울수 없어서 안먹었어요        옛    실시간 예보하고 너무 화가났던         경주 커피 7 0 아덴의 시그니처    ',
#   'total_text': '  경주여행   황리단길 한옥카페추천  카페 아덴 2호점 카페 아덴 2호점 위치   경북  경주 시 사정로 57 운영시간   매일 10시     경주 와서 빵으로 배채울수 없어서 안먹었어요        옛    실시간 예보하고 너무 화가났던         경주 커피 7 0 아덴의 시그니처    '},
#  {'query': '경주 여행',
#   'no': 353,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/794851149/12070266',
#   'description': '일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점    경주 에 대한 아름다움을 느낄 수 있을 거 같은 책이라 기대됩니다',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점    경주 에 대한 아름다움을 느낄 수 있을 거 같은 책이라 기대됩니다'},
#  {'query': '경주 여행',
#   'no': 354,
#   'title': ' 알라딘서재  경주 여행  필수책',
#   'link': 'https://blog.aladin.co.kr/725842246/16721841',
#   'description': '되어주는 책 필요한 지식과 설명  이해를 돕는 사진과 정보 가득한 책 서울편에 이어  경주 편 들고 역사의 땅  경주여행  꿈꾸기  한옥에서 독서모임 하다가 이 책보고 바로 주문하신분들과 또 역사  여행  갈 예정',
#   'total_text': ' 알라딘서재  경주 여행  필수책 되어주는 책 필요한 지식과 설명  이해를 돕는 사진과 정보 가득한 책 서울편에 이어  경주 편 들고 역사의 땅  경주여행  꿈꾸기  한옥에서 독서모임 하다가 이 책보고 바로 주문하신분들과 또 역사  여행  갈 예정'},
#  {'query': '경주 여행',
#   'no': 355,
#   'title': ' 경주여행 3  경주 역에서 걸어서 대릉원까지 대릉원 담장길 걷기 2018 11    ',
#   'link': 'https://khtd1831.tistory.com/597',
#   'description': '이번  여행 은 천천히 걸으며  경주 의 가을을 만끽하는 게 컨셉  마침 가을 분위기 한껏 고조시켜줄    벚나무가 길 좌우로 늘어서 있어  경주 여행  올 때마다 걸어보고 싶었던 길이다  차를 가지고 와서 늘 휙    ',
#   'total_text': ' 경주여행 3  경주 역에서 걸어서 대릉원까지 대릉원 담장길 걷기 2018 11     이번  여행 은 천천히 걸으며  경주 의 가을을 만끽하는 게 컨셉  마침 가을 분위기 한껏 고조시켜줄    벚나무가 길 좌우로 늘어서 있어  경주 여행  올 때마다 걸어보고 싶었던 길이다  차를 가지고 와서 늘 휙    '},
#  {'query': '경주 여행',
#   'no': 356,
#   'title': 'Knowledge Box     경주 여행    슈만과 클라라',
#   'link': 'https://touchsoul.tistory.com/40',
#   'description': ' 경주 역 도착     제일 먼저 간 곳은 슈만과클라라 라는 cafe를 갔다  위치는 요기   여기를 버스를 타고 가려고 했는데 버스가 너무 안와서 택시를 타고 가기로 했다  그러나 다음 문제가 있었다  계속  여행 을    ',
#   'total_text': 'Knowledge Box     경주 여행    슈만과 클라라  경주 역 도착     제일 먼저 간 곳은 슈만과클라라 라는 cafe를 갔다  위치는 요기   여기를 버스를 타고 가려고 했는데 버스가 너무 안와서 택시를 타고 가기로 했다  그러나 다음 문제가 있었다  계속  여행 을    '},
#  {'query': '경주 여행',
#   'no': 357,
#   'title': ' 경주여행  첨성대 대릉원 주차',
#   'link': 'https://itshue.tistory.com/1028',
#   'description': '주차장 대릉원 주차장 여기도 매표를 해야 들어갈 수 있어서 그냥 혼자  여행 이고 하다보니 굳이 들어갈 필요성을 못 느꼈네요  편하게 드라이브삼아 둘러본  경주  그리고 그곳에서 만난 첨성대',
#   'total_text': ' 경주여행  첨성대 대릉원 주차 주차장 대릉원 주차장 여기도 매표를 해야 들어갈 수 있어서 그냥 혼자  여행 이고 하다보니 굳이 들어갈 필요성을 못 느꼈네요  편하게 드라이브삼아 둘러본  경주  그리고 그곳에서 만난 첨성대'},
#  {'query': '경주 여행',
#   'no': 358,
#   'title': ' 경주여행 2303       ',
#   'link': 'https://ydc0420.tistory.com/1677',
#   'description': '봄꽃 찾아   경주 로 갔습니다  벌써 3월 마지막 월요일  찾아간  경주 는 벚꽃과 상춘객으로 많이 붐볐습니다  집에서 점심을 먹고  집사람과 국도를 타고  천천히 올라가는 길 곳곳엔 벚꽃이 제자랑에 열중이라  참    ',
#   'total_text': ' 경주여행 2303        봄꽃 찾아   경주 로 갔습니다  벌써 3월 마지막 월요일  찾아간  경주 는 벚꽃과 상춘객으로 많이 붐볐습니다  집에서 점심을 먹고  집사람과 국도를 타고  천천히 올라가는 길 곳곳엔 벚꽃이 제자랑에 열중이라  참    '},
#  {'query': '경주 여행',
#   'no': 359,
#   'title': ' 경주 여행   경주  황리단길 맛집  여도가주 영업종료',
#   'link': 'https://ggumosi.tistory.com/1396',
#   'description': '오늘은   경주 맛집  황리단길맛집  여주가주 이야기 함께해요  다만  현재 여도가주는 없어졌다는 게        저희  여행 의 기록이기도 해서 그냥 포스팅을 진행하니 이점 참고하세요  한옥의 외관이 눈길을 끌었던    ',
#   'total_text': ' 경주 여행   경주  황리단길 맛집  여도가주 영업종료 오늘은   경주 맛집  황리단길맛집  여주가주 이야기 함께해요  다만  현재 여도가주는 없어졌다는 게        저희  여행 의 기록이기도 해서 그냥 포스팅을 진행하니 이점 참고하세요  한옥의 외관이 눈길을 끌었던    '},
#  {'query': '경주 여행',
#   'no': 360,
#   'title': ' 경주여행 13  경주 역앞 성동시장 구경 가을 기차 여행  피날레 2018 11 9 ',
#   'link': 'https://khtd1831.tistory.com/607',
#   'description': '  즐거웠다   경주  가을 기차 여행   단풍을 맘껏 누리고 돌아가는 길  발떼샷 한 컷  노란 은행낙엽 위에 올려놓고 찍어야 하는데 아숩다  언니들 수고했어염  숙소를 변경한 건 신의 한 수  지도자 언니 짝짝짝  ',
#   'total_text': ' 경주여행 13  경주 역앞 성동시장 구경 가을 기차 여행  피날레 2018 11 9    즐거웠다   경주  가을 기차 여행   단풍을 맘껏 누리고 돌아가는 길  발떼샷 한 컷  노란 은행낙엽 위에 올려놓고 찍어야 하는데 아숩다  언니들 수고했어염  숙소를 변경한 건 신의 한 수  지도자 언니 짝짝짝  '},
#  {'query': '경주 여행',
#   'no': 361,
#   'title': '  경주여행   황리단길 주전부리   황금십원빵  황남옥수수  청년분식',
#   'link': 'https://jisuni-1116.tistory.com/338',
#   'description': ' 경주  황리단길 주전부리  저녁먹기전에 출출해서 황리단길에 있는 주전부리 사서 우선 급한불 끄려 함  결론부터 말하자면 청년분식  십원빵  황남 옥수수 모두 아쉽     청년분식 비쥬얼이 우릴 유혹함 뭔가    ',
#   'total_text': '  경주여행   황리단길 주전부리   황금십원빵  황남옥수수  청년분식  경주  황리단길 주전부리  저녁먹기전에 출출해서 황리단길에 있는 주전부리 사서 우선 급한불 끄려 함  결론부터 말하자면 청년분식  십원빵  황남 옥수수 모두 아쉽     청년분식 비쥬얼이 우릴 유혹함 뭔가    '},
#  {'query': '경주 여행',
#   'no': 362,
#   'title': '안녕 2014년  경주여행  3',
#   'link': 'https://lje77777.tistory.com/2740',
#   'description': '2014년 마지막 날  경주 에서 멋진 선물을 받은거 같다  눈발이 날리기 시작한다  그리고 금방 하얀 세상으로 변한다  눈길을 산책하고    불국사역에서 기차를 타고  여행 을 마무리 한다  다시 화창해진 하늘       ',
#   'total_text': '안녕 2014년  경주여행  3 2014년 마지막 날  경주 에서 멋진 선물을 받은거 같다  눈발이 날리기 시작한다  그리고 금방 하얀 세상으로 변한다  눈길을 산책하고    불국사역에서 기차를 타고  여행 을 마무리 한다  다시 화창해진 하늘       '},
#  {'query': '경주 여행',
#   'no': 363,
#   'title': '  경주여행    경주 야경또다른매력  월정교',
#   'link': 'https://foursmallthing.tistory.com/445',
#   'description': '분위기 꼭 해지는 저녁에 월정교 방문하시길 추천드립니다 꺄 불켜진 월정교 신나서 사진찍는 중 월정교 야경을 마지막으로  경주 를 떠나갑니다 여기는 신라니까   신라 해장국    즐거웠던  경주여행 이었습니다',
#   'total_text': '  경주여행    경주 야경또다른매력  월정교 분위기 꼭 해지는 저녁에 월정교 방문하시길 추천드립니다 꺄 불켜진 월정교 신나서 사진찍는 중 월정교 야경을 마지막으로  경주 를 떠나갑니다 여기는 신라니까   신라 해장국    즐거웠던  경주여행 이었습니다'},
#  {'query': '경주 여행',
#   'no': 364,
#   'title': '  경주여행   황남맷돌순두부   두부보쌈  제육  순두부찌개 그리고 호    ',
#   'link': 'https://jisuni-1116.tistory.com/336',
#   'description': ' 경주  황남맷돌순두부 영업시간이 8시30분까지   경주  황리단길을 시작으로 어지간한  밥집 은 영업마감이      경주 는 진짜 고기가 맛있는듯   두부도 순두부찌개도 맛나고  호랑이막걸리도 완전 맛있어서    ',
#   'total_text': '  경주여행   황남맷돌순두부   두부보쌈  제육  순두부찌개 그리고 호      경주  황남맷돌순두부 영업시간이 8시30분까지   경주  황리단길을 시작으로 어지간한  밥집 은 영업마감이      경주 는 진짜 고기가 맛있는듯   두부도 순두부찌개도 맛나고  호랑이막걸리도 완전 맛있어서    '},
#  {'query': '경주 여행',
#   'no': 365,
#   'title': ' 경주 여행  마치고 울주',
#   'link': 'https://lje77777.tistory.com/9000',
#   'description': '새벽에 비가오다가 그친다  하늘이 늠 예쁘다   경주 월드앞 블루판다에서 점심  맛있고 친절하다  떡갈비도 맛나고 계란찜도 굿  산풍경도 좋고 꽃도 예쁘다  행복한  경주  울주  여행 이다 ',
#   'total_text': ' 경주 여행  마치고 울주 새벽에 비가오다가 그친다  하늘이 늠 예쁘다   경주 월드앞 블루판다에서 점심  맛있고 친절하다  떡갈비도 맛나고 계란찜도 굿  산풍경도 좋고 꽃도 예쁘다  행복한  경주  울주  여행 이다 '},
#  {'query': '경주 여행',
#   'no': 366,
#   'title': ' 경주여행  서출지  23  7 28 ',
#   'link': 'https://juju3ju.tistory.com/15720933',
#   'description': '더운날씨 촬영에 임했던 네분의 사진가들에게 도촬하게 된점 미안하게 생각하며 더운날씨  경주  여러곳 촬영에 대작 담으시고 무사히 귀가 하셨을것을 빌어마지 않습니다 ',
#   'total_text': ' 경주여행  서출지  23  7 28  더운날씨 촬영에 임했던 네분의 사진가들에게 도촬하게 된점 미안하게 생각하며 더운날씨  경주  여러곳 촬영에 대작 담으시고 무사히 귀가 하셨을것을 빌어마지 않습니다 '},
#  {'query': '경주 여행',
#   'no': 367,
#   'title': ' 알라딘서재  100자평  우리 아이 첫  경주 여행  1',
#   'link': 'https://blog.aladin.co.kr/772691194/5984734',
#   'description': '우리 아이 첫  경주 여행  1   세계 문화유산을 찾아서  개정판   답사 바로하기 역사 바로보기 2 박광일 전향이 글   여행 이야기 기획   삼성당   2011년 4월 평점   초등학교 학생들이  경주  수학 여행  가기 전에    ',
#   'total_text': ' 알라딘서재  100자평  우리 아이 첫  경주 여행  1 우리 아이 첫  경주 여행  1   세계 문화유산을 찾아서  개정판   답사 바로하기 역사 바로보기 2 박광일 전향이 글   여행 이야기 기획   삼성당   2011년 4월 평점   초등학교 학생들이  경주  수학 여행  가기 전에    '},
#  {'query': '경주 여행',
#   'no': 368,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/751700224/12081863',
#   'description': '일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이     경주 땅에 묻힌 타임캡슐을 타고 신라를  여행 해보는 특별한 시간이 될것 같네요 ',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이     경주 땅에 묻힌 타임캡슐을 타고 신라를  여행 해보는 특별한 시간이 될것 같네요 '},
#  {'query': '경주 여행',
#   'no': 369,
#   'title': ' 경주여행  안압지 야경투어',
#   'link': 'https://yeoin67.tistory.com/12408533',
#   'description': '방문한날은 아마도 보름달이 뜨는날이었나보다  하늘엔 휘황청밝은 발이 연못에 빠져있어 야경과 함께 정말 멋진 야경을 보여줬다  이래서  경주여행 객을 밤이면 밤마다 이곳 안압지를 찾게하나보다 ',
#   'total_text': ' 경주여행  안압지 야경투어 방문한날은 아마도 보름달이 뜨는날이었나보다  하늘엔 휘황청밝은 발이 연못에 빠져있어 야경과 함께 정말 멋진 야경을 보여줬다  이래서  경주여행 객을 밤이면 밤마다 이곳 안압지를 찾게하나보다 '},
#  {'query': '경주 여행',
#   'no': 370,
#   'title': ' 경주 여행 ',
#   'link': 'https://lje77777.tistory.com/8998',
#   'description': '오늘은  경주여행 하는 날  날씨가 더우니 마을식당에서 맛난 양념게장점심먹고 힐튼 호텔에서 커피한잔  보문단지 푸른 나무감상하며 씨유 커피한잔과 스콘의 행복   경주 월드 새 관람차가 보인다  한번 타볼까    ',
#   'total_text': ' 경주 여행  오늘은  경주여행 하는 날  날씨가 더우니 마을식당에서 맛난 양념게장점심먹고 힐튼 호텔에서 커피한잔  보문단지 푸른 나무감상하며 씨유 커피한잔과 스콘의 행복   경주 월드 새 관람차가 보인다  한번 타볼까    '},
#  {'query': '경주 여행',
#   'no': 371,
#   'title': ' 알라딘서재  100자평  우리 아이 첫  경주 여행  2',
#   'link': 'https://blog.aladin.co.kr/746800163/7207522',
#   'description': '우리 아이 첫  경주 여행  2   땅 속에서 찾아 낸 신라의 꿈   답사 바로하기 역사 바로보기 13 박광일    2004년 7월 평점   구판절판  경주 여행  갈 때 들고간 책이다  아이들 눈높이에 맞춰진 책이다 ',
#   'total_text': ' 알라딘서재  100자평  우리 아이 첫  경주 여행  2 우리 아이 첫  경주 여행  2   땅 속에서 찾아 낸 신라의 꿈   답사 바로하기 역사 바로보기 13 박광일    2004년 7월 평점   구판절판  경주 여행  갈 때 들고간 책이다  아이들 눈높이에 맞춰진 책이다 '},
#  {'query': '경주 여행',
#   'no': 372,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/756464110/12193888',
#   'description': '일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점   유익한 책인 것 같아요',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점   유익한 책인 것 같아요'},
#  {'query': '경주 여행',
#   'no': 373,
#   'title': ' 알라딘서재 역사 관심 갖기 시작해서 함께 읽었어요',
#   'link': 'https://blog.aladin.co.kr/735088274/14888282',
#   'description': '갖길래  경주 여행 을 생각하고 있었는데   경주 를 그리는 마음을 접하게 됐어요   경주 에 좋은 기억을 가지고 있는데  아이도 신라를 배운 뒤라 그런지 책을 읽는 동안 배운 내용을 생각하며   경주 의 유적지들을    ',
#   'total_text': ' 알라딘서재 역사 관심 갖기 시작해서 함께 읽었어요 갖길래  경주 여행 을 생각하고 있었는데   경주 를 그리는 마음을 접하게 됐어요   경주 에 좋은 기억을 가지고 있는데  아이도 신라를 배운 뒤라 그런지 책을 읽는 동안 배운 내용을 생각하며   경주 의 유적지들을    '},
#  {'query': '경주 여행',
#   'no': 374,
#   'title': '3월의  경주여행 2 ',
#   'link': 'https://lje77777.tistory.com/7133',
#   'description': '매화와 산수유 만발  보문단지 호수가 산책  행복한  경주여행  마무리 ',
#   'total_text': '3월의  경주여행 2  매화와 산수유 만발  보문단지 호수가 산책  행복한  경주여행  마무리 '},
#  {'query': '경주 여행',
#   'no': 375,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/799707122/12072476',
#   'description': '일상이 고고학  나 혼자  경주 여행  일상이 시리즈 3 황윤 지음   책읽는고양이   2020년 10월 평점    경주  마니아가 알려주는  경주  탐방기라 그런지  경주 에 대한 알찬 설명들이 좋습니다 ',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  일상이 고고학  나 혼자  경주 여행  일상이 시리즈 3 황윤 지음   책읽는고양이   2020년 10월 평점    경주  마니아가 알려주는  경주  탐방기라 그런지  경주 에 대한 알찬 설명들이 좋습니다 '},
#  {'query': '경주 여행',
#   'no': 376,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/719693118/12070050',
#   'description': '일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점   아름다운  경주 의 풍경에 고고학을 더하여 우리의  여행 에 지적 힐링을 안겨줘서    ',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점   아름다운  경주 의 풍경에 고고학을 더하여 우리의  여행 에 지적 힐링을 안겨줘서    '},
#  {'query': '경주 여행',
#   'no': 377,
#   'title': '  경주여행   주상절리   경주  스탬프투어 그 첫번째 목적지  주상절    ',
#   'link': 'https://0572.tistory.com/352',
#   'description': ' 경주여행    스탬프투어   주상절리   해변둘레길  경주  주상절리 파도소리길 드디어 시작되는  경주여행   여행 에 대한 설램 때문이었을까  오랫만에 밤잠을 설치다가 깨서 시계를 보니 6시가 조금 되지 않은 시간    ',
#   'total_text': '  경주여행   주상절리   경주  스탬프투어 그 첫번째 목적지  주상절      경주여행    스탬프투어   주상절리   해변둘레길  경주  주상절리 파도소리길 드디어 시작되는  경주여행   여행 에 대한 설램 때문이었을까  오랫만에 밤잠을 설치다가 깨서 시계를 보니 6시가 조금 되지 않은 시간    '},
#  {'query': '경주 여행',
#   'no': 378,
#   'title': '2FeRed s Conundrum of Life      경주여행   불국사  황남빵  교리김밥  산내소    ',
#   'link': 'https://2fered.tistory.com/150',
#   'description': 'Theme 불국사  황남빵  교리김밥  산내소고기 울산  Comments 후배녀석과 같이 갔던 짧은 1박2일의  경주   울산 여행  불국사에서 승의군과 천마총에서 첨성대쪽으로 난 길을 내려오다가 있는 나무그늘 내부전경       ',
#   'total_text': '2FeRed s Conundrum of Life      경주여행   불국사  황남빵  교리김밥  산내소     Theme 불국사  황남빵  교리김밥  산내소고기 울산  Comments 후배녀석과 같이 갔던 짧은 1박2일의  경주   울산 여행  불국사에서 승의군과 천마총에서 첨성대쪽으로 난 길을 내려오다가 있는 나무그늘 내부전경       '},
#  {'query': '경주 여행',
#   'no': 379,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/755897129/12092169',
#   'description': '개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점   어려서 그냥 학교에서 갔던  경주 가 지금 커서 공부하고 가니 또 다른 느낌이었습니다  꼭 읽어보시고  경주여행  가보세요',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점   어려서 그냥 학교에서 갔던  경주 가 지금 커서 공부하고 가니 또 다른 느낌이었습니다  꼭 읽어보시고  경주여행  가보세요'},
#  {'query': '경주 여행',
#   'no': 380,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/744378253/12092231',
#   'description': '혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점    경주  이야기는 봐도봐도 들어도들어도 재미있는거 같습니다  작가님의 혼자  경주 여행 기 기대해봅니다 ',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점    경주  이야기는 봐도봐도 들어도들어도 재미있는거 같습니다  작가님의 혼자  경주 여행 기 기대해봅니다 '},
#  {'query': '경주 여행',
#   'no': 381,
#   'title': ' 경주 여행 ',
#   'link': 'https://lje77777.tistory.com/8912',
#   'description': '매화꽃과 산수유 예쁜  경주 로 간다  날씨가 늠 따뜻하다  바람도 많이 불고 봄햇살은 따뜻  점심먹고 늘 궁금해 했었던 황룡원을 돌아봤다  동국재단에서 운영하는 연수원인데 넘 웅장하고 잘꾸며져있다     ',
#   'total_text': ' 경주 여행  매화꽃과 산수유 예쁜  경주 로 간다  날씨가 늠 따뜻하다  바람도 많이 불고 봄햇살은 따뜻  점심먹고 늘 궁금해 했었던 황룡원을 돌아봤다  동국재단에서 운영하는 연수원인데 넘 웅장하고 잘꾸며져있다     '},
#  {'query': '경주 여행',
#   'no': 382,
#   'title': '  경주 여행   맷돌순부두 옆집 정화 송이 순두부   맛집의 옆집',
#   'link': 'https://kym850523.tistory.com/3689',
#   'description': ' 여행 지 아니라도 가격은 비싸니까  기본 반찬 셋팅 생선구이가 나와서 후배가 맛있게 섬세하게 발라줬다  하얀 순두부가 있었다니  맑은 순두부는 처음본다  파전도 하나  주문   경주  새송이 생탁주도 주문  낮술    ',
#   'total_text': '  경주 여행   맷돌순부두 옆집 정화 송이 순두부   맛집의 옆집  여행 지 아니라도 가격은 비싸니까  기본 반찬 셋팅 생선구이가 나와서 후배가 맛있게 섬세하게 발라줬다  하얀 순두부가 있었다니  맑은 순두부는 처음본다  파전도 하나  주문   경주  새송이 생탁주도 주문  낮술    '},
#  {'query': '경주 여행',
#   'no': 383,
#   'title': '  경주여행   경주 남산 칠불암 가는길',
#   'link': 'https://rlawogur119.tistory.com/8500498',
#   'description': ' 경주  톨케이트입니다  경주 에 진입하였읍니다 서라벌 휴게소입니다 나는 통일전 주차장에 주차 하지 아니하고 염불사지 삼층석탑옆에 주차하였다 여기는 일찍 도착하여야 주차할수있다 나는 아침 7시에    ',
#   'total_text': '  경주여행   경주 남산 칠불암 가는길  경주  톨케이트입니다  경주 에 진입하였읍니다 서라벌 휴게소입니다 나는 통일전 주차장에 주차 하지 아니하고 염불사지 삼층석탑옆에 주차하였다 여기는 일찍 도착하여야 주차할수있다 나는 아침 7시에    '},
#  {'query': '경주 여행',
#   'no': 384,
#   'title': ' 경주 여행 ',
#   'link': 'https://kwk776.tistory.com/225',
#   'description': '국내 여행  사진 국내 테마 여행   경주 여행  Theodor 2017  4  18  08 11 벚꽃이 거의 떨어지고 새잎이 나는 시기라 아쉬움 속에  경주 에 가다  대능원 출입문과 대능원의 소나무 숲 천마총 안압지 분황사 모전석탑   원래    ',
#   'total_text': ' 경주 여행  국내 여행  사진 국내 테마 여행   경주 여행  Theodor 2017  4  18  08 11 벚꽃이 거의 떨어지고 새잎이 나는 시기라 아쉬움 속에  경주 에 가다  대능원 출입문과 대능원의 소나무 숲 천마총 안압지 분황사 모전석탑   원래    '},
#  {'query': '경주 여행',
#   'no': 385,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/library24/12079724',
#   'description': '일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점   이런 책 너무 좋아함  더구나  경주 라서 너무 마음에 듦  중학교 수학 여행 으로 왔던    ',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점   이런 책 너무 좋아함  더구나  경주 라서 너무 마음에 듦  중학교 수학 여행 으로 왔던    '},
#  {'query': '경주 여행',
#   'no': 386,
#   'title': '  경주여행   힐튼호텔',
#   'link': 'https://youjingk.tistory.com/1121',
#   'description': '한국에는 서울과  경주 에 호텔 체인이 있다  이상 두산백과  참고로  미국의 저명한 모델이자    철저히 손님을 배려한 호텔  그래서 2박 3일  경주여행 은 더 즐거울 수밖에 없었다 ',
#   'total_text': '  경주여행   힐튼호텔 한국에는 서울과  경주 에 호텔 체인이 있다  이상 두산백과  참고로  미국의 저명한 모델이자    철저히 손님을 배려한 호텔  그래서 2박 3일  경주여행 은 더 즐거울 수밖에 없었다 '},
#  {'query': '경주 여행',
#   'no': 387,
#   'title': ' 경주여행  토함산 단풍터널   자연이 그려 낸 수채화     17년11월17일    ',
#   'link': 'https://skdywjd25.tistory.com/5059',
#   'description': ' 경주 로 떠나는 단풍 여행 은 그윽한 숲길 두 곳을 느긋이 걷는 일이었다  불국사와 석굴암을 잇는 토함산 숲길과 함월산 수렛제를 넘는 고갯길은 굳이 신라 역사를 몰라도 걷기에 좋은 길이다   경주  시내를    ',
#   'total_text': ' 경주여행  토함산 단풍터널   자연이 그려 낸 수채화     17년11월17일      경주 로 떠나는 단풍 여행 은 그윽한 숲길 두 곳을 느긋이 걷는 일이었다  불국사와 석굴암을 잇는 토함산 숲길과 함월산 수렛제를 넘는 고갯길은 굳이 신라 역사를 몰라도 걷기에 좋은 길이다   경주  시내를    '},
#  {'query': '경주 여행',
#   'no': 388,
#   'title': ' 경주여행  배롱나무가 핀 첨성대 야경 16년8월18일 ',
#   'link': 'https://skdywjd25.tistory.com/4273',
#   'description': ' 경주 를 수학 여행  때 다녀오고 단 한번도 가지 않은 사람  심지어 자녀의 역사유적 답사에 동행해서    이런 곳은 아무리 생각해봐도 국내에선  경주  밖에 없다   경주여행 의 특징 중 하나는 평온한 자연    ',
#   'total_text': ' 경주여행  배롱나무가 핀 첨성대 야경 16년8월18일   경주 를 수학 여행  때 다녀오고 단 한번도 가지 않은 사람  심지어 자녀의 역사유적 답사에 동행해서    이런 곳은 아무리 생각해봐도 국내에선  경주  밖에 없다   경주여행 의 특징 중 하나는 평온한 자연    '},
#  {'query': '경주 여행',
#   'no': 389,
#   'title': ' 경주 황리단길카페   경주여행  카페능',
#   'link': 'https://younghyun416.tistory.com/257',
#   'description': '카페능은 황리단길 메인거리내에 위치해 있어서 거리를 둘러보며 뚜벅이  여행 중에 쉬기 좋은 곳입니다  인테리어도 예쁘게 되어 있어서 더욱 눈길이 가는 카페입니다   경주 황리단길카페   경주여행  카페능 날씨    ',
#   'total_text': ' 경주 황리단길카페   경주여행  카페능 카페능은 황리단길 메인거리내에 위치해 있어서 거리를 둘러보며 뚜벅이  여행 중에 쉬기 좋은 곳입니다  인테리어도 예쁘게 되어 있어서 더욱 눈길이 가는 카페입니다   경주 황리단길카페   경주여행  카페능 날씨    '},
#  {'query': '경주 여행',
#   'no': 390,
#   'title': '경북 여행   경주여행   경주 가볼만한곳 국밥맛집   수백당  경주 보문단    ',
#   'link': 'https://jjyh.tistory.com/676',
#   'description': 'com 633 경북 여행   경주여행   경주 가볼만한곳  경주 교촌마을   교촌홍보관  아이와가볼만한곳 가족과가볼 2024년8월31일 가족과 함께한  여행  기록오늘은 가족 모임이 있어서 경북  경주 에 가게 되었어요3시에    ',
#   'total_text': '경북 여행   경주여행   경주 가볼만한곳 국밥맛집   수백당  경주 보문단     com 633 경북 여행   경주여행   경주 가볼만한곳  경주 교촌마을   교촌홍보관  아이와가볼만한곳 가족과가볼 2024년8월31일 가족과 함께한  여행  기록오늘은 가족 모임이 있어서 경북  경주 에 가게 되었어요3시에    '},
#  {'query': '경주 여행',
#   'no': 391,
#   'title': '  경주 여행   불국사역   경주 역에서 동대구까지 기차 무궁화호  시간    ',
#   'link': 'https://okyoungi.tistory.com/50',
#   'description': ' 경주 역은 시외 고속 버스터미널과 신 경주 역이 모두 거리가 있어서  어디로  여행 할 지에 따라 대중 교통 종류가 달라지는데  서울이나 대전    경주  까지 2시간 이상 걸리는 먼 코스라고    ',
#   'total_text': '  경주 여행   불국사역   경주 역에서 동대구까지 기차 무궁화호  시간      경주 역은 시외 고속 버스터미널과 신 경주 역이 모두 거리가 있어서  어디로  여행 할 지에 따라 대중 교통 종류가 달라지는데  서울이나 대전    경주  까지 2시간 이상 걸리는 먼 코스라고    '},
#  {'query': '경주 여행',
#   'no': 392,
#   'title': ' 경주 여행  ',
#   'link': 'https://lje77777.tistory.com/7405',
#   'description': '파란 하늘 흰구름 동동 맑고 아름다운 날 신나게 고속도로를 달려  경주 로 간다  오늘은 힐링  여행   산송이 한우구이  언양불고기와 더덕구이로 자알 먹고 빵이랑 라떼한잔하고 노천온천으로 간다  파란하늘 보며    ',
#   'total_text': ' 경주 여행   파란 하늘 흰구름 동동 맑고 아름다운 날 신나게 고속도로를 달려  경주 로 간다  오늘은 힐링  여행   산송이 한우구이  언양불고기와 더덕구이로 자알 먹고 빵이랑 라떼한잔하고 노천온천으로 간다  파란하늘 보며    '},
#  {'query': '경주 여행',
#   'no': 393,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/726717191/12073576',
#   'description': '2020년 10월 평점   매년 봄 가을이면  경주여행 을 꿈꾸지만 아직도 실천 못하고 있는 사람입니다     이 책 읽고  경주 여행 가면 좀 더 알차게  경주 를 느낄 수 있을 것 같아 기대되요  열심히 읽어보겠습니다 ',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  2020년 10월 평점   매년 봄 가을이면  경주여행 을 꿈꾸지만 아직도 실천 못하고 있는 사람입니다     이 책 읽고  경주 여행 가면 좀 더 알차게  경주 를 느낄 수 있을 것 같아 기대되요  열심히 읽어보겠습니다 '},
#  {'query': '경주 여행',
#   'no': 394,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/777273104/12193401',
#   'description': '지음   책읽는고양이   2020년 10월 평점    경주  정말 좋아하는 도시입니다  시간 여행 하는 기분이 들어서 행복하거든요  코로나때문에  경주여행 도 꿈이 되어버렸네요  이 책으로 나 혼자  경주여행  해보고 싶네요 ',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  지음   책읽는고양이   2020년 10월 평점    경주  정말 좋아하는 도시입니다  시간 여행 하는 기분이 들어서 행복하거든요  코로나때문에  경주여행 도 꿈이 되어버렸네요  이 책으로 나 혼자  경주여행  해보고 싶네요 '},
#  {'query': '경주 여행',
#   'no': 395,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/711388105/12082369',
#   'description': '일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점   수학 여행  이후로 가보지 못했던  경주여행 에 대해 다시 생각해보게 되네요   경주 와    ',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점   수학 여행  이후로 가보지 못했던  경주여행 에 대해 다시 생각해보게 되네요   경주 와    '},
#  {'query': '경주 여행',
#   'no': 396,
#   'title': '  경주여행 1   경주  나정맛집  나정에가면  라면맛집   경주 에도 바다가    ',
#   'link': 'https://vonvon1009.tistory.com/33',
#   'description': '나정에가면  경주여행  스토리 올려드릴께요   경주 에도 바다가 있다는 사실 아시나요   여행 지를 정하면서 저는 바다가 가고 싶었고  남편은 역사를 좋아해서 유적지가 있는  경주 에 가고 싶어했어요  그러던    ',
#   'total_text': '  경주여행 1   경주  나정맛집  나정에가면  라면맛집   경주 에도 바다가     나정에가면  경주여행  스토리 올려드릴께요   경주 에도 바다가 있다는 사실 아시나요   여행 지를 정하면서 저는 바다가 가고 싶었고  남편은 역사를 좋아해서 유적지가 있는  경주 에 가고 싶어했어요  그러던    '},
#  {'query': '경주 여행',
#   'no': 397,
#   'title': '가을  경주 여행  ',
#   'link': 'https://lje77777.tistory.com/7492',
#   'description': ' 경주  도착  오늘은 작년 여름  경주여행 코스였던 서출지와 통일전 그리고 산림 연구원 둘러보고 핑크뮬리 예쁜 첨성대주변  황리단길 구경하고 헉헉  점심먹고 커피한잔 하면서 숨돌린다  조금씩 가을이 찾아오는    ',
#   'total_text': '가을  경주 여행    경주  도착  오늘은 작년 여름  경주여행 코스였던 서출지와 통일전 그리고 산림 연구원 둘러보고 핑크뮬리 예쁜 첨성대주변  황리단길 구경하고 헉헉  점심먹고 커피한잔 하면서 숨돌린다  조금씩 가을이 찾아오는    '},
#  {'query': '경주 여행',
#   'no': 398,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/787898106/12069804',
#   'description': '일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점    경주 를 가본 적이 몇 번 있지만  제대로된 구경을 해보지 못 한 것 같네요  코로나로    ',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  일상이 고고학  나 혼자  경주 여행    개정증보판   일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점    경주 를 가본 적이 몇 번 있지만  제대로된 구경을 해보지 못 한 것 같네요  코로나로    '},
#  {'query': '경주 여행',
#   'no': 399,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/loser/12194523',
#   'description': '앞서  출간된 일상이 고고학  나혼자 백제  여행  에 이어 이번엔  경주 여행 입니다  전작인 백제  여행 이 만족 스러웠던 분들이라면 이번  경주 여행 에도 무조건 탑승 하시길 바랍니다 ',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  앞서  출간된 일상이 고고학  나혼자 백제  여행  에 이어 이번엔  경주 여행 입니다  전작인 백제  여행 이 만족 스러웠던 분들이라면 이번  경주 여행 에도 무조건 탑승 하시길 바랍니다 '},
#  {'query': '경주 여행',
#   'no': 400,
#   'title': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행 ',
#   'link': 'https://blog.aladin.co.kr/790354138/12089807',
#   'description': '일상이 고고학  나 혼자  경주 여행    개정증보판  일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점   수학 여행  때는 역사의 의미를 모르고 지나쳤지만 이제는 작은 풍경 하나하나에서    ',
#   'total_text': ' 알라딘서재  100자평  일상이 고고학  나 혼자  경주 여행  일상이 고고학  나 혼자  경주 여행    개정증보판  일상이 고고학 시리즈 2 황윤 지음   책읽는고양이   2020년 10월 평점   수학 여행  때는 역사의 의미를 모르고 지나쳤지만 이제는 작은 풍경 하나하나에서    '}]

# %%
import time
queries = ['경주 여행', '전주 여행']
max_start = 5
result_total = []
for query in queries:
    for start in range(1, max_start+1):
        print(f'{query} 읽어오는 중...{start}/{max_start}')
        result_total.extend(get_search_item_return(query, start))
        time.sleep(0.5)
# Out:
# 경주 여행 읽어오는 중...1/5
# 경주 여행 읽어오는 중...2/5
# 경주 여행 읽어오는 중...3/5
# 경주 여행 읽어오는 중...4/5
# 경주 여행 읽어오는 중...5/5
# 전주 여행 읽어오는 중...1/5
# 전주 여행 읽어오는 중...2/5
# 전주 여행 읽어오는 중...3/5
# 전주 여행 읽어오는 중...4/5
# 전주 여행 읽어오는 중...5/5

# %%
result_total
# Out:
# [{'title': '블로그제목', 'link': '링크', 'description': '요약내용', 'total_text': '전부다'},
#  {'title': '블로그제목', 'link': '링크', 'description': '요약내용', 'total_text': '전부다'},
#  {'title': '블로그제목', 'link': '링크', 'description': '요약내용', 'total_text': '전부다'},
#  {'title': '블로그제목', 'link': '링크', 'description': '요약내용', 'total_text': '전부다'},
#  {'title': '블로그제목', 'link': '링크', 'description': '요약내용', 'total_text': '전부다'},
#  {'title': '블로그제목', 'link': '링크', 'description': '요약내용', 'total_text': '전부다'},
#  {'title': '블로그제목', 'link': '링크', 'description': '요약내용', 'total_text': '전부다'},
#  {'title': '블로그제목', 'link': '링크', 'description': '요약내용', 'total_text': '전부다'},
#  {'title': '블로그제목', 'link': '링크', 'description': '요약내용', 'total_text': '전부다'},
#  {'title': '블로그제목', 'link': '링크', 'description': '요약내용', 'total_text': '전부다'},
#  {'title': '블로그제목', 'link': '링크', 'description': '요약내용', 'total_text': '전부다'},
#  {'title': '블로그제목', 'link': '링크', 'description': '요약내용', 'total_text': '전부다'},
#  {'title': '블로그제목', 'link': '링크', 'description': '요약내용', 'total_text': '전부다'},
#  {'title': '블로그제목', 'link': '링크', 'description': '요약내용', 'total_text': '전부다'},
#  {'title': '블로그제목', 'link': '링크', 'description': '요약내용', 'total_text': '전부다'},
#  {'title': '블로그제목', 'link': '링크', 'description': '요약내용', 'total_text': '전부다'},
#  {'title': '블로그제목', 'link': '링크', 'description': '요약내용', 'total_text': '전부다'},
#  {'title': '블로그제목', 'link': '링크', 'description': '요약내용', 'total_text': '전부다'},
#  {'title': '블로그제목', 'link': '링크', 'description': '요약내용', 'total_text': '전부다'},
#  {'title': '블로그제목', 'link': '링크', 'description': '요약내용', 'total_text': '전부다'}]
