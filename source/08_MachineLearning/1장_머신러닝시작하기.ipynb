# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:98% !important;}
div.cell.code_cell.rendered{width:98%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:22pt;}
.inner_cell{font-size:22pt;}
div.text_cell_render pre code {font-size:22pt; line-height:30px;}
div.output {font-size:20pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:22pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render li, div.text_cell_render p{width:95% !important;font-size:20pt;padding:5px; line-height:30px;}
table.dataframe{font-size:22px;}
table td, th{font-size:16px;}
table{ margin-left:0 !important;   /* 왼쪽 여백 0 */}
</style>
"""))
# Out:
# <style>
# div.container{width:98% !important;}
# div.cell.code_cell.rendered{width:98%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:22pt;}
# .inner_cell{font-size:22pt;}
# div.text_cell_render pre code {font-size:22pt; line-height:30px;}
# div.output {font-size:20pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:22pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render li, div.text_cell_render p{width:95% !important;font-size:20pt;padding:5px; line-height:30px;}
# table.dataframe{font-size:22px;}
# table td, th{font-size:16px;}
# table{ margin-left:0 !important;   /* 왼쪽 여백 0 */}
# </style>

# %% [markdown]
# <font size="6" color="red"><b>ch1. 머신러닝 시작하기</b></font>
#
# # 1절. 머신러닝 개요
# - insight : 탐색적 자료 분석(EDA) ; Pandas, Numpy, matplotlib, seaborn
# - optimization : 머신러닝>딥러닝 ; scikit-learn머신러닝, statmodel, scipy, stats통계패키지
# - 머신러닝이란? 학습을 통해 측정된 작업의 성능을 향상
#     * 지도학습(감독학습) : SVM, Decision Tree, Random forest, Logistic Regression,..
#     * 비지도학습(자율학습) : K-means(군집), PCA(주성분분석), ...
#
# # 2절. 데이터 탐색
# ## 2.1 변수의 종류
# - 데이터의 속성에 따라 명목식(남,여), 순서식(상중하, 서열존재), 구간식(간격척도, 순서의 간격의미), 비율식(연속형, 영점존재)으로 분류
# - 변수의 타입에 따라 범주형, 이산형, 연속형
# - 데이터 품질에 따라 특이값(비정상치), 결측값
#
# ## 2.2 통계 요약
# - 중심위치 측도 : 평균, 중앙값, 최빈값
# - 산포 측도 : 왜도, 첨도

# %%
import numpy as np
from scipy.stats import skew, kurtosis # 왜도0, 첨도0이면 정규분포

# %%
# np.random.normal(loc=0.0, scale=1.0, size=tup) : 평균 loc, 표준편차 scale을 갖는 정규분포 랜덤값
data = np.random.normal(0, 1, size=10000000)

# %%
print('평균 :', np.mean(data), data.mean())
print('중위수 :', np.median(data))
print('분산 :', np.var(data), data.var())
print('표준편차 :', np.std(data))
# Out:
# 평균 : 0.00016966750661367633 0.00016966750661367633
# 중위수 : 0.0002324148943149312
# 분산 : 1.0004219133715155 1.0004219133715155
# 표준편차 : 1.000210934439089

# %%
print('왜도 :', skew(data)) # 왜도<0 : 왼쪽 긴꼬리 데이터(오른쪽으로 치우친 데이터)
print('첨도 :', kurtosis(data)) # 양수면 정규분포보다 뽀족한 봉우리 모양의 분포
# Out:
# 왜도 : 0.00027600552792818046
# 첨도 : 0.0027206818994960358

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,1))
plt.hist(data, bins=100)
plt.show()

# %%
from scipy.stats import skewnorm, norm
# a<0:왼쪽꼬리긴데이터(왜도는 아님)
data = skewnorm(a=-5, loc=0, scale=1).rvs(size=10000000)
print('평균 :', np.mean(data))
print('중위수 :', np.median(data))
print('분산 :', np.var(data))
print('표준편차 :', np.std(data))
print('왜도 :', skew(data))
print('첨도 :', kurtosis(data))
plt.figure(figsize=(5,1))
plt.hist(data, bins=300)
plt.show()
# Out:
# 평균 : -0.7828311659133244
# 중위수 : -0.6751957911198568
# 분산 : 0.38769326635610313
# 표준편차 : 0.6226501958211393
# 왜도 : -0.8503711141766432
# 첨도 : 0.7068213439098203

# %% [markdown]
# ## 2.3 기초통계량
# - describe()함수
#     * 수치형 : 최소, 최대, 사분위수, 평균, 표준편차, 분산...
#     * 범주형 : unique수, 최빈데이터, 최빈데이터빈도

# %%
from seaborn import load_dataset
